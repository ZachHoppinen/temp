# %%
import pandas as pd
from glob import glob

# %%
glob('../../../modeling/output/sensitivity/*.pro')
# Out:
# ['../../../modeling/output/sensitivity/ID1_EXP_9_320.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_15_338.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_12_322.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_16_340.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_8_322.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_10_326.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_17_330.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_14_320.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_18_322.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_9_338.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_16_328.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_14_324.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_13_328.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_14_338.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_16_330.pro',
#  '../../../modeling/output/sensitivity/ID1_EXP_12_334.pro',
# ...
