# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../snowschool/wx_data/winter_20_21_clean.csv')
df = df[1:]
df.index = pd.to_datetime(df[df.columns[0]])
df = df[(df.index > '11-18-2020') & (df.index < '12-17-2020')]

# %%
df.air_temp_28.astype('f4').plot()
# Out:
# <AxesSubplot:xlabel='Unnamed: 0'>

# %%
df.air_temp_1.astype('f4').plot()
# Out:
# <AxesSubplot:xlabel='Unnamed: 0'>

# %%
s = df.snow_depth_1.astype('f4')/1000
s.plot()
# Out:
# <AxesSubplot:xlabel='Unnamed: 0'>

# %%
temp_list = [col for col in df.columns if ('soil_temp' in col) or ('air_temp' in col)]
sub_list = []
for col in temp_list:
   if int(col.split('_')[-1])<11 and int(col.split('_')[-1])>1 or 'soil' in col:
       sub_list.append(col)
df_new = df[sub_list]

# %%
df_new
# Out:
#                           air_temp_2 air_temp_3 air_temp_4 air_temp_5  \
# Unnamed: 0
# 2020-11-18 01:00:00+00:00       0.08       0.04       0.04       0.01
# 2020-11-18 02:00:00+00:00       0.07       0.03       0.03        0.0
# 2020-11-18 03:00:00+00:00       0.11       0.07       0.05       0.04
# 2020-11-18 04:00:00+00:00       0.12       0.08       0.07       0.06
# 2020-11-18 05:00:00+00:00       0.11       0.08       0.06       0.05
# ...                              ...        ...        ...        ...
# 2020-12-16 19:00:00+00:00      -0.13      -0.47      -0.78      -0.83
# 2020-12-16 20:00:00+00:00      -0.14      -0.46      -0.75       -0.8
# 2020-12-16 21:00:00+00:00      -0.11      -0.45      -0.76      -0.79
# 2020-12-16 22:00:00+00:00      -0.09      -0.41      -0.73      -0.75
# 2020-12-16 23:00:00+00:00      -0.08       -0.4      -0.71      -0.73
#
#                           air_temp_6 air_temp_7 air_temp_8 air_temp_9  \
# Unnamed: 0
# ...

# %%
df_new.to_csv('../../modeling/iFlowWindows/data/test.csv', date_format= '%Y-%m-%d %H:%M:%S')
